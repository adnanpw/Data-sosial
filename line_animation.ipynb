# %%
from plotly.offline import init_notebook_mode, plot
from IPython.display import display, HTML

import pandas as pd

init_notebook_mode(connected=True)

url = 'https://raw.githubusercontent.com/adnanpw/Data-sosial/master/Data_pengeluaran_2000-2017.csv'
dataset = pd.read_csv(url)

years = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']
# make list of continents
continents = []
for continent in dataset['Kabupaten']:
    if continent not in continents:
        continents.append(continent)
# make figure
figure = {
    'data': [],
    'layout': {},
    'frames': []
}

# fill in most of layout
figure['layout']= {'title':'Pengeluaran Konsumsi Kabupaten Tegal dan Pantura Barat 2000-2017'}
figure['layout']['xaxis'] = {'range': [25, 70], 'title': 'Non Makanan'}
figure['layout']['yaxis'] = {'range': [25, 80], 'title': 'Makanan'}
figure['layout']['hovermode'] = 'closest'
figure['layout']['sliders'] = {
    'args': [
        'transition', {
            'duration': 400,
            'easing': 'cubic-in-out'
        }
    ],
    'initialValue': '2000',
    'plotlycommand': 'animate',
    'values': years,
    'visible': True
}
figure['layout']['updatemenus'] = [
    {
        'buttons': [
            {
                'args': [None, {'frame': {'duration': 500, 'redraw': False},
                         'fromcurrent': True, 'transition': {'duration': 300, 'easing': 'quadratic-in-out'}}],
                'label': 'Play',
                'method': 'animate'
            },
            {
                'args': [[None], {'frame': {'duration': 0, 'redraw': False}, 'mode': 'immediate',
                'transition': {'duration': 0}}],
                'label': 'Pause',
                'method': 'animate'
            }
        ],
        'direction': 'left',
        'pad': {'r': 10, 't': 87},
        'showactive': False,
        'type': 'buttons',
        'x': 0.1,
        'xanchor': 'right',
        'y': 0,
        'yanchor': 'top'
    }
]

sliders_dict = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20},
        'prefix': 'Year:',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300, 'easing': 'cubic-in-out'},
    'pad': {'b': 10, 't': 50},
    'len': 0.9,
    'x': 0.1,
    'y': 0,
    'steps': []
}

# make data
year = 2000
for continent in continents:
    dataset_by_year = dataset[dataset['Tahun'] == year]
    dataset_by_year_and_cont = dataset_by_year[dataset_by_year['Kabupaten'] == continent]

    data_dict = {
        'x': list(dataset_by_year_and_cont['Non Makanan']),
        'y': list(dataset_by_year_and_cont['Makanan']),
        'mode': 'liners+markers',
        'text': list(dataset_by_year_and_cont['Kabupaten']),
        'marker': {
            'sizemode': 'area',
            'sizeref': 1000,
            'size': list(dataset_by_year_and_cont['Penduduk'])
        },
        'name': continent
    }
    figure['data'].append(data_dict)
    
# make frames
for year in years:
    frame = {'data': [], 'name': str(year)}
    for continent in continents:
        dataset_by_year = dataset[dataset['Tahun'] == int(year)]
        dataset_by_year_and_cont = dataset_by_year[dataset_by_year['Kabupaten'] == continent]

        data_dict = {
            'x': list(dataset_by_year_and_cont['Non Makanan']),
            'y': list(dataset_by_year_and_cont['Makanan']),
            'mode': 'liners+markers',
            'text': list(dataset_by_year_and_cont['Kabupaten']),
            'marker': {
                'sizemode': 'area',
                'sizeref': 1000,
                'size': list(dataset_by_year_and_cont['Penduduk'])
            },
            'name': continent
        }
        frame['data'].append(data_dict)

    figure['frames'].append(frame)
    slider_step = {'args': [
        [year],
        {'frame': {'duration': 300, 'redraw': False},
         'mode': 'immediate',
       'transition': {'duration': 300}}
     ],
     'label': year,
     'method': 'animate'}
    sliders_dict['steps'].append(slider_step)

    
figure['layout']['sliders'] = [sliders_dict]

plot(figure)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-a607fb43de3c> in <module>()
#     139 figure['layout']['sliders'] = [sliders_dict]
#     140
# --> 141 plot(figure)
#
# ~/anaconda3/lib/python3.7/site-packages/plotly/offline/offline.py in plot(figure_or_data, show_link, link_text, validate, output_type, include_plotlyjs, filename, auto_open, image, image_filename, image_width, image_height, config, include_mathjax)
#     616     plot_html, plotdivid, width, height = _plot_html(
#     617         figure_or_data, config, validate,
# --> 618         '100%', '100%', global_requirejs=False)
#     619
#     620     # Build resize_script
#
# ~/anaconda3/lib/python3.7/site-packages/plotly/offline/offline.py in _plot_html(figure_or_data, config, validate, default_width, default_height, global_requirejs)
#     242                default_height, global_requirejs):
#     243
# --> 244     figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     245
#     246     width = figure.get('layout', {}).get('width', default_width)
#
# ~/anaconda3/lib/python3.7/site-packages/plotly/tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#    1506
#    1507         try:
# -> 1508             figure = Figure(**figure).to_dict()
#    1509         except exceptions.PlotlyError as err:
#    1510             raise exceptions.PlotlyError("Invalid 'figure_or_data' argument. "
#
# ~/anaconda3/lib/python3.7/site-packages/plotly/graph_objs/_figure.py in __init__(self, data, layout, frames, skip_invalid)
#     409             is invalid AND skip_invalid is False
#     410         """
# --> 411         super(Figure, self).__init__(data, layout, frames, skip_invalid)
#     412
#     413     def add_area(
#
# ~/anaconda3/lib/python3.7/site-packages/plotly/basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid)
#     138         # ### Import traces ###
#     139         data = self._data_validator.validate_coerce(data,
# --> 140                                                     skip_invalid=skip_invalid)
#     141
#     142         # ### Save tuple of trace objects ###
#
# ~/anaconda3/lib/python3.7/site-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v, skip_invalid)
#    2280                     else:
#    2281                         trace = self.class_map[trace_type](
# -> 2282                             skip_invalid=skip_invalid, **v_copy)
#    2283                         res.append(trace)
#    2284                 else:
#
# ~/anaconda3/lib/python3.7/site-packages/plotly/graph_objs/_scatter.py in __init__(self, arg, cliponaxis, connectgaps, customdata, customdatasrc, dx, dy, error_x, error_y, fill, fillcolor, groupnorm, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertext, hovertextsrc, ids, idssrc, legendgroup, line, marker, mode, name, opacity, orientation, r, rsrc, selected, selectedpoints, showlegend, stackgaps, stackgroup, stream, t, text, textfont, textposition, textpositionsrc, textsrc, tsrc, uid, unselected, visible, x, x0, xaxis, xcalendar, xsrc, y, y0, yaxis, ycalendar, ysrc, **kwargs)
#    2324         self['marker'] = marker if marker is not None else _v
#    2325         _v = arg.pop('mode', None)
# -> 2326         self['mode'] = mode if mode is not None else _v
#    2327         _v = arg.pop('name', None)
#    2328         self['name'] = name if name is not None else _v
#
# ~/anaconda3/lib/python3.7/site-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    2797             # ### Handle simple property ###
#    2798             else:
# -> 2799                 self._set_prop(prop, value)
#    2800
#    2801         # Handle non-scalar case
#
# ~/anaconda3/lib/python3.7/site-packages/plotly/basedatatypes.py in _set_prop(self, prop, val)
#    3033                 return
#    3034             else:
# -> 3035                 raise err
#    3036
#    3037         # val is None
#
# ~/anaconda3/lib/python3.7/site-packages/plotly/basedatatypes.py in _set_prop(self, prop, val)
#    3028         validator = self._validators.get(prop)
#    3029         try:
# -> 3030             val = validator.validate_coerce(val)
#    3031         except ValueError as err:
#    3032             if self._skip_invalid:
#
# ~/anaconda3/lib/python3.7/site-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v)
#    1566             validated_v = self.vc_scalar(v)
#    1567             if validated_v is None:
# -> 1568                 self.raise_invalid_val(v)
#    1569
#    1570             v = validated_v
#
# ~/anaconda3/lib/python3.7/site-packages/_plotly_utils/basevalidators.py in raise_invalid_val(self, v, inds)
#     252             typ=type_str(v),
#     253             v=repr(v),
# --> 254             valid_clr_desc=self.description()))
#     255
#     256     def raise_invalid_elements(self, invalid_els):
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'mode' property of scatter
#         Received value: 'liners+markers'
#
#     The 'mode' property is a flaglist and may be specified
#     as a string containing:
#       - Any combination of ['lines', 'markers', 'text'] joined with '+' characters
#         (e.g. 'lines+markers')
#         OR exactly one of ['none'] (e.g. 'none')
